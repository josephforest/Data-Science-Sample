# %%
import pandas as pd
import numpy as np

# %%
seri = pd.Series([1,2,3,4])
seri
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
type(seri)
# Out:
# pandas.core.series.Series

# %%
seri.dtype
# Out:
# dtype('int64')

# %%
seri.mean()
# Out:
# 2.5

# %%
seri.axes
# Out:
# [RangeIndex(start=0, stop=4, step=1)]

# %%
seri.size
# Out:
# 4

# %%
seri.ndim
# Out:
# 1

# %%
seri.shape
# Out:
# (4,)

# %%
seri.head(2) # ilk iki hane
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
seri.tail(2) # son iki satır
# Out:
# 2    3
# 3    4
# dtype: int64

# %%
seri = pd.Series(np.random.randint(3,17, size = 20 ))
seri
# Out:
# 0     16
# 1      5
# 2     13
# 3     11
# 4     15
# 5      6
# 6      7
# 7     11
# 8     15
# 9     12
# 10     5
# 11    15
# 12    13
# 13    10
# 14     3
# 15     3
# 16     7
# 17    12
# 18     8
# 19    14
# dtype: int32

# %%
seri = pd.Series(np.random.randint(1,10, size = 5))
seri
# Out:
# 0    7
# 1    8
# 2    1
# 3    1
# 4    6
# dtype: int32

# %%
seri.index = [list("abcde")]
seri
# Out:
# a    7
# b    8
# c    1
# d    1
# e    6
# dtype: int32

# %%
seri["a"]
# Out:
# 7

# %%
seri["a":"d"]
# Out:
# a    7
# b    8
# c    1
# d    1
# dtype: int32

# %%
seri1 = pd.Series(np.random.randint(3,100, size = 5))
seri2 = pd.Series(np.random.randint(4,100, size = 5))

# %%
seri3 = pd.concat([seri1,seri2],ignore_index = True)
seri3
# Out:
# 0    55
# 1     4
# 2    22
# 3    61
# 4    19
# 5    84
# 6     5
# 7     4
# 8    41
# 9    38
# dtype: int32

# %%
seri.index
# Out:
# MultiIndex([('a',),
#             ('b',),
#             ('c',),
#             ('d',),
#             ('e',)],
#            )

# %%
seri.values
# Out:
# array([7, 8, 1, 1, 6])

# %%
list(seri.items())
# Out:
# [(('a',), 7), (('b',), 8), (('c',), 1), (('d',), 1), (('e',), 6)]

# %%
"a" in seri
# Out:
# True

# %%
8 in seri.values
# Out:
# True

# %%
sozluk = {"hello":"Merhaba", "Age":"Yaş", "Computer": "Bilgisyar"}
seri = pd.Series(sozluk)

# %%
seri
# Out:
# hello         Merhaba
# Age               Yaş
# Computer    Bilgisyar
# dtype: object

# %%
seri.index
# Out:
# Index(['hello', 'Age', 'Computer'], dtype='object')

# %%
list(seri.items())
# Out:
# [('hello', 'Merhaba'), ('Age', 'Yaş'), ('Computer', 'Bilgisyar')]

# %%
seri = pd.Series(np.arange(1,13,2))
seri
# Out:
# 0     1
# 1     3
# 2     5
# 3     7
# 4     9
# 5    11
# dtype: int32

# %%
seri.mean()
# Out:
# 5.0

# %%
seri.std()
# Out:
# 3.1622776601683795

# %%
seri.var()
# Out:
# 10.0

# %%
seri.median()  #
# Out:
# 6.0

# %%
seri = pd.Series(np.random.randint(3,100, size = 8))

# %%
seri
# Out:
# 0    73
# 1    98
# 2    54
# 3    46
# 4    30
# 5    82
# 6    17
# 7    28
# dtype: int32

# %%
seri.mean()
# Out:
# 53.5

# %%
seri.median()
# Out:
# 50.0

# %%
seri.sort_values()
# Out:
# 6    17
# 7    28
# 4    30
# 3    46
# 2    54
# 0    73
# 5    82
# 1    98
# dtype: int32

# %%
df = pd.DataFrame(np.random.randint(1,100, size = 10),columns=["Değer"])
df
# Out:
#    Değer
# 0     60
# 1     82
# 2     84
# 3     22
# 4     26
# 5     73
# 6     72
# 7     51
# 8     94
# 9     89

# %%
df = pd.DataFrame(np.random.randint(1,100, size = (3,4)))
df
# Out:
#     0   1   2   3
# 0  17   6  41  19
# 1  27   5  27  50
# 2  11  65  65  81

# %%
df = pd.DataFrame(np.random.randint(1,100, size =(4,5)),
                  index = ["a","b","c","d"],
                 columns=["deg1","deg2","deg3","deg4","deg5"])

# %%
df
# Out:
#    deg1  deg2  deg3  deg4  deg5
# a    36    19    60    55    82
# b    25    63    48    35     1
# c    84    61    54    39    79
# d    15    61    99    89    86

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# deg1    int32
# deg2    int32
# deg3    int32
# deg4    int32
# deg5    int32
# dtype: object

# %%
df.axes
# Out:
# [Index(['a', 'b', 'c', 'd'], dtype='object'),
#  Index(['deg1', 'deg2', 'deg3', 'deg4', 'deg5'], dtype='object')]

# %%
df.size
# Out:
# 20

# %%
df.shape
# Out:
# (4, 5)

# %%
df.ndim
# Out:
# 2

# %%
df.values
# Out:
# array([[36, 19, 60, 55, 82],
#        [25, 63, 48, 35,  1],
#        [84, 61, 54, 39, 79],
#        [15, 61, 99, 89, 86]])

# %%
df.keys
# Out:
# <bound method NDFrame.keys of    deg1  deg2  deg3  deg4  deg5
# a    36    19    60    55    82
# b    25    63    48    35     1
# c    84    61    54    39    79
# d    15    61    99    89    86>

# %%
df_list = df.values

# %%
df.head(3)
# Out:
#    deg1  deg2  deg3  deg4  deg5
# a    36    19    60    55    82
# b    25    63    48    35     1
# c    84    61    54    39    79

# %%
df.tail(2)
# Out:
#    deg1  deg2  deg3  deg4  deg5
# c    84    61    54    39    79
# d    15    61    99    89    86

# %%
s1 = np.random.randint(1,100,size = 5)
s2 = np.random.randint(1,100,size = 5)
s3 = np.random.randint(1,100,size = 5)

# %%
number = {"var1":s1, "var2":s2,"var3":s3}

# %%
df = pd.DataFrame(number,index = [list("abcde")])
df
# Out:
#    var1  var2  var3
# a     4    77    51
# b    58    42    51
# c     1    84    72
# d    12    28     6
# e    74    70    24

# %%
df
# Out:
#    var1  var2  var3
# a     4    77    51
# b    58    42    51
# c     1    84    72
# d    12    28     6
# e    74    70    24

# %%
df[0:2]
# Out:
#    var1  var2  var3
# a     4    77    51
# b    58    42    51

# %%
df.iloc[0] #seri olarak getirdi
# Out:
# var1     4
# var2    77
# var3    51
# Name: (a,), dtype: int32

# %%
df.iloc[[0]]  # dataframe olarak getirdi
# Out:
#    var1  var2  var3
# a     4    77    51

# %%
df.loc["a"] # index değerine göre getiriyor
# Out:
#    var1  var2  var3
# a     4    77    51

# %%
df.iloc[[3]]
# Out:
#    var1  var2  var3
# d    12    28     6

# %%
df.loc[["d"]]
# Out:
#    var1  var2  var3
# d    12    28     6

# %%
df.iloc[2:4,1:3] # stop değerleri dahil değil
# Out:
#    var2  var3
# c    84    72
# d    28     6

# %%
df.loc["c":"d", "var2":"var3"] # stop indexleri dahil
# Out:
#    var2  var3
# c    84    72
# d    28     6

# %%
df
# Out:
#    var1  var2  var3
# a     4    77    51
# b    58    42    51
# c     1    84    72
# d    12    28     6
# e    74    70    24

# %%
df = pd.DataFrame(np.random.randint(1,100,size = (3,5)),
                 index = ["deg1 deg2 deg3".split()],
                 columns = [list("abcde")])

# %%
df
# Out:
#        a   b   c   d   e
# deg1  32  56  82  37  48
# deg2  27  40   1  71  96
# deg3  22  48   7   7  98

# %%
df.iloc[1,1]
# Out:
# 40

# %%
df.iloc[2,2]
# Out:
# 7

# %%
df.loc["deg2":"deg3","d":"e"]
# Out:
#        d   e
# deg2  71  96
# deg3   7  98

# %%
df
# Out:
#        a   b   c   d   e
# deg1  32  56  82  37  48
# deg2  27  40   1  71  96
# deg3  22  48   7   7  98

# %%
df.drop("deg1",axis=0)  # satır siliyor.
# Out:
#        a   b  c   d   e
# deg2  27  40  1  71  96
# deg3  22  48  7   7  98

# %%
df.drop("deg2")  # axis default 0 olduğu için yazmaya gerek yok
# Out:
#        a   b   c   d   e
# deg1  32  56  82  37  48
# deg3  22  48   7   7  98

# %%
df.drop("a",axis= 1)
# Out:
#        b   c   d   e
# deg1  56  82  37  48
# deg2  40   1  71  96
# deg3  48   7   7  98

# %%
arr1 = np.random.randint(2,20, size = (3,6))
arr2 = np.random.randint(1,10, size = (3,5))

# %%
arr1
# Out:
# array([[ 3, 14, 10, 11, 14, 13],
#        [ 5, 17,  7, 16,  2, 12],
#        [15, 16, 10,  2, 12,  7]])

# %%
arr2
# Out:
# array([[2, 8, 6, 9, 1],
#        [9, 3, 5, 6, 9],
#        [7, 1, 3, 8, 1]])

# %%
arr3 = np.concatenate((arr1,arr2),axis = 1)

# %%
arr3
# Out:
# array([[ 3, 14, 10, 11, 14, 13,  2,  8,  6,  9,  1],
#        [ 5, 17,  7, 16,  2, 12,  9,  3,  5,  6,  9],
#        [15, 16, 10,  2, 12,  7,  7,  1,  3,  8,  1]])

# %%
df = pd.DataFrame(arr3, index = ["satır1 satır2 satır3".split()],
                 columns=[list("abcdefghjkl")])
df
# Out:
#          a   b   c   d   e   f  g  h  j  k  l
# satır1   3  14  10  11  14  13  2  8  6  9  1
# satır2   5  17   7  16   2  12  9  3  5  6  9
# satır3  15  16  10   2  12   7  7  1  3  8  1

# %%
df.iloc[1,7]
# Out:
# 3

# %%
df.loc["satır2","d"]
# Out:
#          d
# satır2  16

# %%
df
# Out:
#          a   b   c   d   e   f  g  h  j  k  l
# satır1   3  14  10  11  14  13  2  8  6  9  1
# satır2   5  17   7  16   2  12  9  3  5  6  9
# satır3  15  16  10   2  12   7  7  1  3  8  1

# %%
df.drop("satır1")
# Out:
#          a   b   c   d   e   f  g  h  j  k  l
# satır2   5  17   7  16   2  12  9  3  5  6  9
# satır3  15  16  10   2  12   7  7  1  3  8  1

# %%
df
# Out:
#          a   b   c   d   e   f  g  h  j  k  l
# satır1   3  14  10  11  14  13  2  8  6  9  1
# satır2   5  17   7  16   2  12  9  3  5  6  9
# satır3  15  16  10   2  12   7  7  1  3  8  1

# %%
df.loc[:,"b"].sum()
# Out:
# b    47
# dtype: int64

# %%
df = pd.DataFrame(np.random.randint(1,100,size = (5,4)))

# %%
df
# Out:
#     0   1   2   3
# 0   8  68  76  64
# 1  90   1  44  86
# 2  87  61  46  78
# 3  50  32  80  35
# 4  82  50  42  50

# %%
df1 = pd.DataFrame({"çalışanlar":["ali","veli","mahmut"],
                    "işe_başlama":[2019,2020,2021]})
df2 = pd.DataFrame({"çalışanlar":["ali","veli","mahmut"],
                   "departman": ["ik","it","muhasebe"]})

# %%
df3= pd.merge(df1,df2)

# %%
df4 = pd.DataFrame({"grup":["Mühendis","It uzman","çaycı"],
                   "çalışanlar":["ali","veli","mahmut"]})

# %%
df4
# Out:
#        grup çalışanlar
# 0  Mühendis        ali
# 1  It uzman       veli
# 2     çaycı     mahmut

# %%
pd.merge(df3,df4)
# Out:
#   çalışanlar  işe_başlama departman      grup
# 0        ali         2019        ik  Mühendis
# 1       veli         2020        it  It uzman
# 2     mahmut         2021  muhasebe     çaycı
