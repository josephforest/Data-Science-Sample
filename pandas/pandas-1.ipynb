# %% [markdown]
# Indexing, Selecting & Assigning

# %%
import pandas as pd

# %%
wine_reviews = pd.read_csv("../datasets/winemag-data-130k-v2.csv")

# %%
wine_reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
wine_reviews.country  # select column name
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_reviews["country"]  # dict yöntemi ile ilgili coloumn seçtik
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_reviews["country"][1000]
# Out:
# 'US'

# %%
wine_reviews.iloc[1]
# Out:
# Unnamed: 0                                                               1
# country                                                           Portugal
# description              This is ripe and fruity, a wine that is smooth...
# designation                                                       Avidagos
# points                                                                  87
# price                                                                 15.0
# province                                                             Douro
# region_1                                                               NaN
# region_2                                                               NaN
# taster_name                                                     Roger Voss
# taster_twitter_handle                                           @vossroger
# title                        Quinta dos Avidagos 2011 Avidagos Red (Douro)
# ...

# %%
wine_reviews.iloc[:, 1]
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_reviews["country"][100:110]
# Out:
# 100       US
# 101       US
# 102       US
# 103    Chile
# 104    Italy
# 105    Italy
# 106    Italy
# 107    Italy
# 108       US
# 109    Italy
# Name: country, dtype: object

# %%
wine_reviews.loc[:, ['taster_name', 'taster_twitter_handle', 'points']]
# Out:
#                taster_name taster_twitter_handle  points
# 0            Kerin O’Keefe          @kerinokeefe      87
# 1               Roger Voss            @vossroger      87
# 2             Paul Gregutt           @paulgwine       87
# 3       Alexander Peartree                   NaN      87
# 4             Paul Gregutt           @paulgwine       87
# ...                    ...                   ...     ...
# 129966  Anna Lee C. Iijima                   NaN      90
# 129967        Paul Gregutt           @paulgwine       90
# 129968          Roger Voss            @vossroger      90
# 129969          Roger Voss            @vossroger      90
# 129970          Roger Voss            @vossroger      90
#
# [129971 rows x 3 columns]

# %%
wine_reviews.loc[:, ["taster_name", "title", "variety" ]]
# Out:
#                taster_name                                              title  \
# 0            Kerin O’Keefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1               Roger Voss      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2             Paul Gregutt      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3       Alexander Peartree  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4             Paul Gregutt  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# ...                    ...                                                ...
# 129966  Anna Lee C. Iijima  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...
# 129967        Paul Gregutt                  Citation 2004 Pinot Noir (Oregon)
# 129968          Roger Voss  Domaine Gresser 2013 Kritt Gewurztraminer (Als...
# 129969          Roger Voss      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)
# 129970          Roger Voss  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...
#
#                variety
# ...

# %%
wine_reviews.set_index("title").head(3)
# Out:
#                                                Unnamed: 0   country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                       0     Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)           1  Portugal
# Rainstorm 2013 Pinot Gris (Willamette Valley)           2        US
#
#                                                                                      description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)  This is ripe and fruity, a wine that is smooth...
# Rainstorm 2013 Pinot Gris (Willamette Valley)  Tart and snappy, the flavors of lime flesh and...
#
#                                                 designation  points  price  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)              Vulkà Bianco      87    NaN
# Quinta dos Avidagos 2011 Avidagos Red (Douro)      Avidagos      87   15.0
# ...

# %%
wine_reviews.country == "Italy"
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968    False
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
wine_reviews.loc[wine_reviews.country == "Italy",["designation","description",]]
# Out:
#                       designation  \
# 0                    Vulkà Bianco
# 6                         Belsito
# 13                          Rosso
# 22                      Ficiligno
# 24                          Aynat
# ...                           ...
# 129929                        NaN
# 129943                    Adènzia
# 129947                   Symposio
# 129961                        NaN
# 129962  Sàgana Tenuta San Giacomo
#
#                                               description
# 0       Aromas include tropical fruit, broom, brimston...
# 6       Here's a bright, informal red that opens with ...
# 13      This is dominated by oak and oak-driven aromas...
# 22      Delicate aromas recall white flower and citrus...
# 24      Aromas of prune, blackcurrant, toast and oak c...
# ...                                                   ...
# 129929  This luminous sparkler has a sweet, fruit-forw...
# 129943  A blend of Nero d'Avola and Syrah, this convey...
# ...

# %%
# Out:
# 0.15034122996668486
