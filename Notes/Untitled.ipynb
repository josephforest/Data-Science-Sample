# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("world-happiness-report-2021.csv")

# %%
df1=df[['Country name', 'Regional indicator', 'Ladder score',
       'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']].copy()

# %%
df.head(2)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.949      -0.098                      0.186
# 1                         0.946       0.030                      0.179
#
#    Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                      2.43                             1.446
# 1                      2.43                             1.502
#
# ...

# %%
df.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
df1.set_index("Country name", inplace=True)

# %%
df1.head(2)
# Out:
#              Regional indicator  Ladder score  Logged GDP per capita  \
# Country name
# Finland          Western Europe         7.842                 10.775
# Denmark          Western Europe         7.620                 10.933
#
#               Social support  Healthy life expectancy  \
# Country name
# Finland                0.954                     72.0
# Denmark                0.954                     72.7
#
#               Freedom to make life choices  Generosity  \
# Country name
# Finland                              0.949      -0.098
# Denmark                              0.946       0.030
#
#               Perceptions of corruption
# Country name
# Finland                           0.186
# Denmark                           0.179

# %%
df1.reset_index()
# Out:
#     Country name  Regional indicator  Ladder score  Logged GDP per capita  \
# 0        Finland      Western Europe         7.842                 10.775
# 1        Denmark      Western Europe         7.620                 10.933
# 2    Switzerland      Western Europe         7.571                 11.117
# 3        Iceland      Western Europe         7.554                 10.878
# 4    Netherlands      Western Europe         7.464                 10.932
# ..           ...                 ...           ...                    ...
# 144      Lesotho  Sub-Saharan Africa         3.512                  7.926
# 145     Botswana  Sub-Saharan Africa         3.467                  9.782
# 146       Rwanda  Sub-Saharan Africa         3.415                  7.676
# 147     Zimbabwe  Sub-Saharan Africa         3.145                  7.943
# 148  Afghanistan          South Asia         2.523                  7.695
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
df1.columns
# Out:
# Index(['Regional indicator', 'Ladder score', 'Logged GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Regional indicator', 'Ladder score', 'Logged GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df1.set_index('Ladder score', inplace = True)

# %%
df1.head()
# Out:
#              Regional indicator  Logged GDP per capita  Social support  \
# Ladder score
# 7.842            Western Europe                 10.775           0.954
# 7.620            Western Europe                 10.933           0.954
# 7.571            Western Europe                 11.117           0.942
# 7.554            Western Europe                 10.878           0.983
# 7.464            Western Europe                 10.932           0.942
#
#               Healthy life expectancy  Freedom to make life choices  \
# Ladder score
# 7.842                            72.0                         0.949
# 7.620                            72.7                         0.946
# 7.571                            74.4                         0.919
# 7.554                            73.0                         0.955
# 7.464                            72.4                         0.913
#
#               Generosity  Perceptions of corruption
# Ladder score
# ...

# %%
df1.head(2)
# Out:
#   Country name Regional indicator  Ladder score  Logged GDP per capita  \
# 0      Finland     Western Europe         7.842                 10.775
# 1      Denmark     Western Europe         7.620                 10.933
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.954                     72.0                         0.949
# 1           0.954                     72.7                         0.946
#
#    Generosity  Perceptions of corruption
# 0      -0.098                      0.186
# 1       0.030                      0.179

# %%
df1.set_index('Country name', inplace = True)

# %%
df1.shape
# Out:
# (149, 8)

# %%
df1.tail()
# Out:
#               Regional indicator  Ladder score  Logged GDP per capita  \
# Country name
# Lesotho       Sub-Saharan Africa         3.512                  7.926
# Botswana      Sub-Saharan Africa         3.467                  9.782
# Rwanda        Sub-Saharan Africa         3.415                  7.676
# Zimbabwe      Sub-Saharan Africa         3.145                  7.943
# Afghanistan           South Asia         2.523                  7.695
#
#               Social support  Healthy life expectancy  \
# Country name
# Lesotho                0.787                   48.700
# Botswana               0.784                   59.269
# Rwanda                 0.552                   61.400
# Zimbabwe               0.750                   56.201
# Afghanistan            0.463                   52.493
#
#               Freedom to make life choices  Generosity  \
# Country name
# Lesotho                              0.715      -0.131
# Botswana                             0.824      -0.246
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 149 entries, Finland to Afghanistan
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Regional indicator            149 non-null    object
#  1   Ladder score                  149 non-null    float64
#  2   Logged GDP per capita         149 non-null    float64
#  3   Social support                149 non-null    float64
#  4   Healthy life expectancy       149 non-null    float64
#  5   Freedom to make life choices  149 non-null    float64
#  6   Generosity                    149 non-null    float64
#  7   Perceptions of corruption     149 non-null    float64
# dtypes: float64(7), object(1)
# memory usage: 10.5+ KB

# %%
df1.sample(3)
# Out:
#                        Regional indicator  Ladder score  \
# Country name
# Haiti         Latin America and Caribbean         3.615
# Honduras      Latin America and Caribbean         5.919
# Malaysia                   Southeast Asia         5.384
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Haiti                         7.477           0.540                   55.700
# Honduras                      8.648           0.812                   67.300
# Malaysia                     10.238           0.817                   67.102
#
#               Freedom to make life choices  Generosity  \
# Country name
# Haiti                                0.593       0.422
# Honduras                             0.857       0.081
# Malaysia                             0.895       0.125
#
#               Perceptions of corruption
# Country name
# Haiti                             0.721
# Honduras                          0.809
# ...

# %%
df1.describe()
# Out:
#        Ladder score  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.532839               9.432208        0.814745
# std        1.073924               1.158601        0.114889
# min        2.523000               6.635000        0.463000
# 25%        4.852000               8.541000        0.750000
# 50%        5.534000               9.569000        0.832000
# 75%        6.255000              10.421000        0.905000
# max        7.842000              11.647000        0.983000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               149.000000                    149.000000  149.000000
# mean                 64.992799                      0.791597   -0.015134
# std                   6.762043                      0.113332    0.150657
# min                  48.478000                      0.382000   -0.288000
# ...

# %%
q1 = np.percentile(df1['Ladder score'],25)
q1
# Out:
# 4.852

# %%
q3 = np.quantile(df1['Ladder score'],0.75)
q3
# Out:
# 6.255

# %%
iqr = q3 - q1
iqr
# Out:
# 1.4029999999999996

# %%
left = q1 -1.5*iqr
left
# Out:
# 2.747500000000001

# %%
right = q3 + 1.5*iqr
right
# Out:
# 8.359499999999999

# %%
left_outlier = df1[df1['Ladder score']<left]
left_outlier
# Out:
#              Regional indicator  Ladder score  Logged GDP per capita  \
# Country name
# Afghanistan          South Asia         2.523                  7.695
#
#               Social support  Healthy life expectancy  \
# Country name
# Afghanistan            0.463                   52.493
#
#               Freedom to make life choices  Generosity  \
# Country name
# Afghanistan                          0.382      -0.102
#
#               Perceptions of corruption
# Country name
# Afghanistan                       0.924

# %%
right_outlier = df1[df1['Ladder score']>right]
right_outlier
# Out:
# Empty DataFrame
# Columns: [Regional indicator, Ladder score, Logged GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption]
# Index: []

# %%
df1.drop('Afghanistan', axis=0, inplace = True)

# %%
df1.shape
# Out:
# (148, 8)

# %%
df1.isnull().sum()
# Out:
# Regional indicator              0
# Ladder score                    0
# Logged GDP per capita           0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
df1.columns
# Out:
# Index(['Regional indicator', 'Ladder score', 'Logged GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df1.index
# Out:
# Index(['Finland', 'Denmark', 'Switzerland', 'Iceland', 'Netherlands', 'Norway',
#        'Sweden', 'Luxembourg', 'New Zealand', 'Austria',
#        ...
#        'India', 'Burundi', 'Yemen', 'Tanzania', 'Haiti', 'Malawi', 'Lesotho',
#        'Botswana', 'Rwanda', 'Zimbabwe'],
#       dtype='object', name='Country name', length=148)

# %%
df1['Regional indicator'].value_counts()
# Out:
# Sub-Saharan Africa                    36
# Western Europe                        21
# Latin America and Caribbean           20
# Middle East and North Africa          17
# Central and Eastern Europe            17
# Commonwealth of Independent States    12
# Southeast Asia                         9
# South Asia                             6
# East Asia                              6
# North America and ANZ                  4
# Name: Regional indicator, dtype: int64

# %%
df1.loc[['Germany','Ethiopia','Peru','Chad','Japan'],['Freedom to make life choices','Healthy life expectancy']]
# Out:
#               Freedom to make life choices  Healthy life expectancy
# Country name
# Germany                              0.875                   72.500
# Ethiopia                             0.752                   59.000
# Peru                                 0.822                   68.250
# Chad                                 0.579                   48.478
# Japan                                0.796                   75.100

# %%
df1.iloc[[25,52,65,145],[1,7]]
# Out:
#               Ladder score  Perceptions of corruption
# Country name
# Saudi Arabia         6.494                      0.684
# Hungary              5.992                      0.876
# Ecuador              5.764                      0.843
# Botswana             3.467                      0.801

# %%
df1.columns
# Out:
# Index(['Regional indicator', 'Ladder score', 'Logged GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
Let's bring the Happiness score from the countries where in Central and Easter Europe countries
and where perceptions of corruption higher than 0.9

# %%
df1[(df1['Regional indicator'] == 'Central and Eastern Europe' ) & (df1['Perceptions of corruption'] > 0.9)]['Ladder score']
# Out:
# Country name
# Kosovo                    6.372
# Slovakia                  6.331
# Romania                   6.140
# Croatia                   5.882
# Bosnia and Herzegovina    5.813
# Bulgaria                  5.266
# Albania                   5.117
# North Macedonia           5.101
# Name: Ladder score, dtype: float64

# %%
df1.head(1)
# Out:
#              Regional indicator  Ladder score  Logged GDP per capita  \
# Country name
# Finland          Western Europe         7.842                 10.775
#
#               Social support  Healthy life expectancy  \
# Country name
# Finland                0.954                     72.0
#
#               Freedom to make life choices  Generosity  \
# Country name
# Finland                              0.949      -0.098
#
#               Perceptions of corruption
# Country name
# Finland                           0.186

# %%
Let's bring the Happiness score from the countries where in Sub-Saharan Africa countries
or countries where Healthy life expectancy'lower than 50

# %%
df1[(df1['Regional indicator'] == 'Sub-Saharan Africa') | \
    (df1['Healthy life expectancy'] < 50)]\
[['Ladder score']]
# Out:
#                      Ladder score
# Country name
# Mauritius                   6.049
# Congo (Brazzaville)         5.342
# Ivory Coast                 5.306
# Cameroon                    5.142
# Senegal                     5.132
# Ghana                       5.088
# Niger                       5.074
# Gambia                      5.051
# Benin                       5.045
# Guinea                      4.984
# South Africa                4.956
# Gabon                       4.852
# Burkina Faso                4.834
# Mozambique                  4.794
# Nigeria                     4.759
# Mali                        4.723
# Uganda                      4.636
# Liberia                     4.625
# Kenya                       4.607
# Namibia                     4.574
# Chad                        4.355
# Swaziland                   4.308
# Comoros                     4.289
# Ethiopia                    4.275
# Mauritania                  4.227
# Madagascar                  4.208
# ...

# %%
df1.value_counts()
# Out:
# Regional indicator           Ladder score  Logged GDP per capita  Social support  Healthy life expectancy  Freedom to make life choices  Generosity  Perceptions of corruption
# Central and Eastern Europe   5.101         9.693                  0.805           65.474                   0.751                          0.038      0.905                        1
# Sub-Saharan Africa           3.467         9.782                  0.784           59.269                   0.824                         -0.246      0.801                        1
#                              3.600         6.958                  0.537           57.948                   0.780                          0.038      0.729                        1
#                              3.623         7.876                  0.702           57.999                   0.833                          0.183      0.577                        1
# ...

# %%
Let's randomly bring 7 countries with their 'Regional indicator','Ladder score',
'Perceptions of corruption' scores
Condition : Those countries are not in 
    Western Europe or their 'Perceptions of corruption' 
    scores are not bigger than 0.66

# %%
df1[(df1['Regional indicator'] != 'Western Europe') | (df1['Perceptions of corruption'] <= 0.66)]\
.sample(7)[['Regional indicator','Ladder score','Perceptions of corruption']]
# Out:
#                            Regional indicator  Ladder score  \
# Country name
# Bolivia           Latin America and Caribbean         5.716
# Lebanon          Middle East and North Africa         4.584
# Rwanda                     Sub-Saharan Africa         3.415
# France                         Western Europe         6.690
# North Macedonia    Central and Eastern Europe         5.101
# Hungary            Central and Eastern Europe         5.992
# Malta                          Western Europe         6.602
#
#                  Perceptions of corruption
# Country name
# Bolivia                              0.839
# Lebanon                              0.898
# Rwanda                               0.167
# France                               0.571
# North Macedonia                      0.905
# Hungary                              0.876
# Malta                                0.653

# %%
df1['new'] = (df1['Ladder score'] + df1['Perceptions of corruption']) / 2
df1[['new']]
# Out:
#                  new
# Country name
# Finland       4.0140
# Denmark       3.8995
# Switzerland   3.9315
# Iceland       4.1135
# Netherlands   3.9010
# ...              ...
# Malawi        2.1645
# Lesotho       2.2135
# Botswana      2.1340
# Rwanda        1.7910
# Zimbabwe      1.9830
#
# [148 rows x 1 columns]

# %%
df1.drop('new',axis=1,inplace = True)

# %%
'new' in df1.columns
# Out:
# False

# %%
df1.columns
# Out:
# Index(['Regional indicator', 'Ladder score', 'Logged GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
k = {'Regional indicator':"Westen Europe", 'Ladder score':7.6, 'Logged GDP per capita': 10,
       'Social support':0.9, 'Healthy life expectancy':7,
       'Freedom to make life choices':75, 'Generosity':0.3,
       'Perceptions of corruption':0.2}

# %%
df1 = df1.append(pd.DataFrame(k,index=['Joseph']))
df1
# Out:
#              Regional indicator  Ladder score  Logged GDP per capita  \
# Finland          Western Europe         7.842                 10.775
# Denmark          Western Europe         7.620                 10.933
# Switzerland      Western Europe         7.571                 11.117
# Iceland          Western Europe         7.554                 10.878
# Netherlands      Western Europe         7.464                 10.932
# ...                         ...           ...                    ...
# Rwanda       Sub-Saharan Africa         3.415                  7.676
# Zimbabwe     Sub-Saharan Africa         3.145                  7.943
# Turkey            Westen Europe         7.600                 10.000
# Turkey            Westen Europe         7.600                 10.000
# Joseph            Westen Europe         7.600                 10.000
#
#              Social support  Healthy life expectancy  \
# Finland               0.954                   72.000
# ...

# %%
df1.reset_index(inplace = True)

# %%
df1.head(2)
# Out:
#      index Regional indicator  Ladder score  Logged GDP per capita  \
# 0  Finland     Western Europe         7.842                 10.775
# 1  Denmark     Western Europe         7.620                 10.933
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.954                     72.0                         0.949
# 1           0.954                     72.7                         0.946
#
#    Generosity  Perceptions of corruption
# 0      -0.098                      0.186
# 1       0.030                      0.179

# %%
df1.head()
# Out:
#          index Regional indicator  Ladder score  Logged GDP per capita  \
# 0      Finland     Western Europe         7.842                 10.775
# 1      Denmark     Western Europe         7.620                 10.933
# 2  Switzerland     Western Europe         7.571                 11.117
# 3      Iceland     Western Europe         7.554                 10.878
# 4  Netherlands     Western Europe         7.464                 10.932
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.954                     72.0                         0.949
# 1           0.954                     72.7                         0.946
# 2           0.942                     74.4                         0.919
# 3           0.983                     73.0                         0.955
# 4           0.942                     72.4                         0.913
#
#    Generosity  Perceptions of corruption
# 0      -0.098                      0.186
# ...

# %%
'index' in df1.columns
# Out:
# True

# %%
df1.rename(columns={'index':'Country'}, inplace=True)

# %%
df1.head()
# Out:
#        Country Regional indicator  Ladder score  Logged GDP per capita  \
# 0      Finland     Western Europe         7.842                 10.775
# 1      Denmark     Western Europe         7.620                 10.933
# 2  Switzerland     Western Europe         7.571                 11.117
# 3      Iceland     Western Europe         7.554                 10.878
# 4  Netherlands     Western Europe         7.464                 10.932
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.954                     72.0                         0.949
# 1           0.954                     72.7                         0.946
# 2           0.942                     74.4                         0.919
# 3           0.983                     73.0                         0.955
# 4           0.942                     72.4                         0.913
#
#    Generosity  Perceptions of corruption
# 0      -0.098                      0.186
# ...

# %%
df1.set_index(['Regional indicator','Country'], inplace = True)

# %%
df1.head()
# Out:
#                                 Ladder score  Logged GDP per capita  \
# Regional indicator Country
# Western Europe     Finland             7.842                 10.775
#                    Denmark             7.620                 10.933
#                    Switzerland         7.571                 11.117
#                    Iceland             7.554                 10.878
#                    Netherlands         7.464                 10.932
#
#                                 Social support  Healthy life expectancy  \
# Regional indicator Country
# Western Europe     Finland               0.954                     72.0
#                    Denmark               0.954                     72.7
#                    Switzerland           0.942                     74.4
#                    Iceland               0.983                     73.0
#                    Netherlands           0.942                     72.4
#
# ...

# %%
df1.head(10)
# Out:
#                                    Ladder score  Logged GDP per capita  \
# Regional indicator    Country
# Western Europe        Finland             7.842                 10.775
#                       Denmark             7.620                 10.933
#                       Switzerland         7.571                 11.117
#                       Iceland             7.554                 10.878
#                       Netherlands         7.464                 10.932
#                       Norway              7.392                 11.053
#                       Sweden              7.363                 10.867
#                       Luxembourg          7.324                 11.647
# North America and ANZ New Zealand         7.277                 10.643
# Western Europe        Austria             7.268                 10.906
#
#                                    Social support  Healthy life expectancy  \
# Regional indicator    Country
# ...

# %%
def new(a):
    return a**2

# %%
df1['new'] =  df1['Social support'].apply(new)

# %%
df1.head(2)
# Out:
#                             Ladder score  Logged GDP per capita  \
# Regional indicator Country
# Western Europe     Finland         7.842                 10.775
#                    Denmark         7.620                 10.933
#
#                             Social support  Healthy life expectancy  \
# Regional indicator Country
# Western Europe     Finland           0.954                     72.0
#                    Denmark           0.954                     72.7
#
#                             Freedom to make life choices  Generosity  \
# Regional indicator Country
# Western Europe     Finland                         0.949      -0.098
#                    Denmark                         0.946       0.030
#
#                             Perceptions of corruption       new
# Regional indicator Country
# Western Europe     Finland                      0.186  0.910116
#                    Denmark                      0.179  0.910116

# %%
def new2(a,b):
    return a/b

# %%
df1['Healthy life expectancy'] = df1['Healthy life expectancy'].astype(int)
df1['new2'] = np.vectorize(new2)(df1['Social support'],df1['Healthy life expectancy'])

# %%
df1.head()
# Out:
#                                 Ladder score  Logged GDP per capita  \
# Regional indicator Country
# Western Europe     Finland             7.842                 10.775
#                    Denmark             7.620                 10.933
#                    Switzerland         7.571                 11.117
#                    Iceland             7.554                 10.878
#                    Netherlands         7.464                 10.932
#
#                                 Social support  Healthy life expectancy  \
# Regional indicator Country
# Western Europe     Finland               0.954                       72
#                    Denmark               0.954                       72
#                    Switzerland           0.942                       74
#                    Iceland               0.983                       73
#                    Netherlands           0.942                       72
#
# ...

# %%
Based on the our dataset's 'Healthy life expectancy' 
scores, lets make a new column with the name of 
'Explained Healthy life expectancy' with the new values which should consist of:
Let's think 'Healthy life expectancy''s mean score as our threshold.
If 'Healthy life expectancy' is equal and greater than 75% of the 
'Healthy life expectancy' score of the dataset , it should be written 
'Long Life expectancy'
If 'Healthy life expectancy' less than 75% of the 'Healthy life expectancy'
score of the dataset but bigger than our threshold, it should be written 
'Longer than normal expectancy'
-If 'Healthy life expectancy' equal or less than our threshold but bigger
than 25% of the 'Healthy life expectancy' score of the dataset, it should
be written 'Normal life expectancy'
-If 'Healthy life expectancy' equal or less than 25% of the 
'Healthy life expectancy' score of the dataset, it should be written 'Lower life expectancy'

# %%
df.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532839                        0.058752      5.648007
# std        1.073924                        0.022001      1.054330
# min        2.523000                        0.026000      2.596000
# 25%        4.852000                        0.043000      4.991000
# 50%        5.534000                        0.054000      5.625000
# 75%        6.255000                        0.070000      6.344000
# max        7.842000                        0.173000      7.904000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417631               9.432208        0.814745
# std        1.094879               1.158601        0.114889
# min        2.449000               6.635000        0.463000
# 25%        4.706000               8.541000        0.750000
# ...

# %%
def change(x):
    if x >= 69:
        return 'Long Life expectancy'
    elif 64.67 < x < 69:
        return 'Longer than normal expectancy'
    elif 59 < x <= 64.67:
        return 'Normal life expectancy'
    else:
        return ' Lower Life expectancy'

# %%
df1['Explained Healthy Life Expectancy'] = df1['Healthy life expectancy'].apply(change)

# %%
df1.head()
# Out:
#                                 Ladder score  Logged GDP per capita  \
# Regional indicator Country
# Western Europe     Finland             7.842                 10.775
#                    Denmark             7.620                 10.933
#                    Switzerland         7.571                 11.117
#                    Iceland             7.554                 10.878
#                    Netherlands         7.464                 10.932
#
#                                 Social support  Healthy life expectancy  \
# Regional indicator Country
# Western Europe     Finland               0.954                       72
#                    Denmark               0.954                       72
#                    Switzerland           0.942                       74
#                    Iceland               0.983                       73
#                    Netherlands           0.942                       72
#
# ...
